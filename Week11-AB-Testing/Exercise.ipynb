# %% [markdown]
# # Exercise with A/B Testing
#
# ### Prompt
#
# Let’s imagine you work on the For You Page at TikTok. Your team decides that instead of a heart button, they want to change it to star hoping that it will lead to a higher engagement/like rate. The product manager told you that the current conversion rate is about 6% on average throughout the year, and that the team would be happy with an increase of 3%, meaning that the new design will be considered a success if it raises the engagement rate to 9%.
#
# Before rolling out the change, the team would be more comfortable testing it on a small number of users to see how it performs, so you suggest running an A/B test on a subset of the user base users.

# %%
# Packages imports
import numpy as np
import pandas as pd

# probability distributions & statistical functions
import scipy.stats as stats
# estimating statistical models
import statsmodels.stats.api as sms

import matplotlib.pyplot as plt
import seaborn as sns

#rounding function
from math import ceil

# %% [markdown]
# ### Sample Size Calculation

# %%
# Calculate effect size based on our expected rates
effect_size = sms.proportion_effectsize(0.06, 0.09)

# %%
# Calculate sample size needed
require_n = sms.NormalIndPower().solve_power(
    effect_size, power = 0.8, alpha = 0.05, ratio = 1)

require_n = ceil(require_n)
require_n
# Out:
# 1199

# %% [markdown]
# ### Collecting and preparing the data

# %%
# Load the tiktok_data.csv into a dataframe

df = pd.read_csv('tiktok_data.csv')
df.head()
# Out:
#    user_id            timestamp      group button  liked
# 0   767017  2017-01-12 22:58:15    control   star      0
# 1   793849  2017-01-23 22:36:11  treatment   star      0
# 2   905617  2017-01-20 14:12:19  treatment   star      0
# 3   746742  2017-01-23 11:38:30    control  heart      0
# 4   892356   2017-01-05 9:35:15  treatment   star      1

# %%
# Get the info of the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275781 entries, 0 to 275780
# Data columns (total 5 columns):
# user_id      275781 non-null int64
# timestamp    275781 non-null object
# group        275781 non-null object
# button       275781 non-null object
# liked        275781 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 10.5+ MB

# %%
# Make sure all the control group are seeing the star button and viceversa
pd.crosstab(df['group'], df['button'])
# Out:
# button      heart    star
# group
# control    136002    1816
# treatment    1855  136108

# %%
# Check that no users have been sampled multiple times 
session_counts = df['user_id'].value_counts(ascending = False)
multi_user = session_counts[session_counts > 1].count()

multi_user
# Out:
# 3453

# %%
# If there are users who have been sampled multiple times, remove them from the dataframe
users_to_drop = session_counts[session_counts > 1].index
df = df[~df['user_id'].isin(users_to_drop)]
print(df.shape[0])
# Out:
# 268875

# %% [markdown]
# #### Now that our DataFrame is nice and clean, we can proceed and sample n=4720 entries for each of the groups. We can use pandas' DataFrame.sample() method to do this, which will perform Simple Random Sampling for us.

# %%
# Perform simple random sampling to split the data into control and treatment

control_sample = df[df['group'] == 'control'].sample(n=require_n, random_state = 22)
treatment_sample = df[df['group'] == 'treatment'].sample(n=require_n, random_state = 22)

# %%
# Create one table called ab_test that has both the cleaned control and treatment data
ab_test = pd.concat([control_sample, treatment_sample], axis = 0)
ab_test.reset_index(drop = True, inplace = True)
ab_test
# Out:
#       user_id            timestamp      group button  liked
# 0      644761   2017-01-20 5:19:16    control  heart      0
# 1      856804  2017-01-02 23:19:00    control  heart      0
# 2      728826   2017-01-03 4:16:37    control  heart      0
# 3      865441   2017-01-19 3:59:57    control  heart      0
# 4      796969   2017-01-05 4:08:26    control  heart      0
# 5      754519  2017-01-06 20:07:55    control  heart      0
# 6      759201  2017-01-07 10:31:32    control  heart      0
# 7      689346  2017-01-08 13:39:03    control  heart      0
# 8      773513  2017-01-07 20:12:42    control  heart      0
# 9      820713   2017-01-08 9:44:26    control  heart      0
# 10     710494   2017-01-10 3:26:01    control  heart      0
# 11     795356  2017-01-22 17:52:51    control  heart      1
# 12     792420   2017-01-08 3:19:02    control  heart      0
# 13     794662  2017-01-15 23:00:02    control  heart      0
# 14     891280  2017-01-06 11:15:39    control  heart      0
# 15     639596   2017-01-21 2:58:13    control  heart      0
# 16     725675  2017-01-23 18:24:31    control  heart      0
# 17     890970  2017-01-16 21:29:33    control  heart      0
# 18     637202   2017-01-05 7:54:10    control  heart      0
# 19     861407  2017-01-16 19:04:22    control  heart      0
# 20     866774   2017-01-18 4:40:49    control  heart      0
# 21     694337  2017-01-03 18:16:22    control  heart      0
# 22     634984   2017-01-05 3:58:57    control  heart      0
# 23     747151   2017-01-11 0:09:16    control  heart      0
# 24     875454   2017-01-07 5:04:28    control  heart      1
# 25     763266  2017-01-14 18:28:10    control  heart      0
# 26     814098  2017-01-05 13:23:20    control  heart      0
# 27     920351  2017-01-07 19:26:20    control  heart      0
# 28     871293   2017-01-24 7:52:23    control  heart      0
# 29     725378   2017-01-17 1:52:45    control  heart      0
# ...       ...                  ...        ...    ...    ...
# 2368   773197   2017-01-05 0:23:56  treatment   star      0
# 2369   778380   2017-01-05 7:33:56  treatment   star      0
# 2370   732222   2017-01-06 6:18:46  treatment   star      1
# 2371   649459   2017-01-20 9:28:45  treatment   star      0
# 2372   908690  2017-01-03 12:36:11  treatment   star      0
# 2373   707937  2017-01-09 12:55:00  treatment   star      0
# 2374   780622  2017-01-23 23:40:39  treatment   star      1
# 2375   895613   2017-01-23 8:22:04  treatment   star      0
# 2376   813745  2017-01-17 13:52:08  treatment   star      0
# 2377   715127   2017-01-16 7:47:22  treatment   star      0
# 2378   854864   2017-01-21 8:11:37  treatment   star      0
# 2379   758544  2017-01-16 15:31:06  treatment   star      0
# 2380   753392  2017-01-03 12:00:49  treatment   star      0
# 2381   911860  2017-01-10 10:01:03  treatment   star      0
# 2382   938195  2017-01-21 20:46:36  treatment   star      0
# 2383   749618  2017-01-06 16:54:15  treatment   star      1
# 2384   638156  2017-01-19 10:14:09  treatment   star      0
# 2385   847498   2017-01-21 3:54:13  treatment   star      0
# 2386   888160  2017-01-22 18:51:08  treatment   star      0
# 2387   922084  2017-01-02 22:22:39  treatment   star      1
# 2388   683436  2017-01-11 11:44:35  treatment   star      0
# 2389   761351  2017-01-09 11:09:58  treatment   star      0
# 2390   896664  2017-01-20 14:50:42  treatment   star      0
# 2391   783677   2017-01-07 0:11:17  treatment   star      0
# 2392   893840  2017-01-12 18:59:41  treatment   star      0
# 2393   647852   2017-01-16 4:47:04  treatment   star      0
# 2394   814529   2017-01-15 1:01:37  treatment   star      1
# 2395   924465   2017-01-13 8:37:42  treatment   star      0
# 2396   660778   2017-01-12 1:55:29  treatment   star      0
# 2397   868855  2017-01-12 20:23:56  treatment   star      0
#
# [2398 rows x 5 columns]

# %%
# Count the test groups to make sure that they're balanced 

ab_test['group'].value_counts()
# Out:
# treatment    1199
# control      1199
# Name: group, dtype: int64

# %% [markdown]
# ### Analysis Visualization

# %%
# Find the like rate by group
liked_rates = ab_test.groupby('group')['liked']

# Find the Std. deviation of the proportion
std_p = lambda x: np.std(x, ddof = 0)
std_p.__name__ = 'std_p';

# Find the Std. error of the proportion (std / sqrt(n))
se_p = lambda x: stats.sem(x, ddof = 0)
se_p.__name__ = 'se_p';

# Calculate the final like rate
liked_rates = liked_rates.agg([np.mean, std_p, se_p])
liked_rates.columns = ['liked_rate', 'std_deviation', 'std_error']


liked_rates.style.format('{:.3f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >liked_rate</th>        <th class="col_heading level0 col1" >std_deviation</th>        <th class="col_heading level0 col2" >std_error</th>    </tr>    <tr>        <th class="index_name level0" >group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64level0_row0" class="row_heading level0 row0" >control</th>
#                         <td id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64row0_col0" class="data row0 col0" >0.109</td>
#                         <td id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64row0_col1" class="data row0 col1" >0.312</td>
#                         <td id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64row0_col2" class="data row0 col2" >0.009</td>
#             </tr>
#             <tr>
#                         <th id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64level0_row1" class="row_heading level0 row1" >treatment</th>
#                         <td id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64row1_col0" class="data row1 col0" >0.118</td>
#                         <td id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64row1_col1" class="data row1 col1" >0.323</td>
#                         <td id="T_dd05818a_a529_11eb_8d5f_f06e0be46b64row1_col2" class="data row1 col2" >0.009</td>
#             </tr>
#     </tbody></table>

# %%
# Plot the like rate by group on a bar plot

plt.figure(figsize = (8, 7))

sns.barplot(x = ab_test['group'], y = ab_test['liked'], ci = False)

plt.ylim(0, 0.17)
plt.title('Liked rate by group', pad=20)
plt.xlabel('Group', labelpad=15)
plt.ylabel('Liked (proportion)', labelpad=15);

# %% [markdown]
# ### Testing for Stat Sig

# %%
from statsmodels.stats.proportion import proportions_ztest, proportion_confint

# Get the like count for both control and treatment groups
control_results = ab_test[ab_test['group'] =='control']['liked']
treatment_results = ab_test[ab_test['group']== 'treatment']['liked']


# Get the number of samples in both groups
n_con = control_results.count()
n_treat = treatment_results.count()

# Sum up the number of successes (likes) in both groups
successes = [control_results.sum(), treatment_results.sum()]
nobs = [n_con, n_treat]

# %%
# Find the z statistic and p value for proportions based on normal ztest

z_stat, pval = proportions_ztest(successes, nobs = nobs)
# Find the confidence intervals for each test group
(lower_con, lower_treat), (upper_con, upper_treat) = proportion_confint(successes,
                                                                       nobs = nobs,
                                                                       alpha = 0.5)

# %%
# print z statistic
print(f'z statistic: {z_stat:.2f}')
# print p-value
print(f'p-value: {pval:.3f}')
# print ci 95% for control group
print(f'ci 95% for control group: [{lower_con:.3f}, {upper_con:.3f}]')
# print ci 95% for treatment group
print(f'ci 95% for treatment group: [{lower_treat:.3f}, {upper_treat:.3f}]')
# Out:
# z statistic: -0.71
# p-value: 0.479
# ci 95% for control group: [0.103, 0.115]
# ci 95% for treatment group: [0.112, 0.125]

# %% [markdown]
# ### Were the results signficant?

# %%
liked_rates.style.format('{:.3f}')
# Out:
# <style  type="text/css" >
# </style><table id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >liked_rate</th>        <th class="col_heading level0 col1" >std_deviation</th>        <th class="col_heading level0 col2" >std_error</th>    </tr>    <tr>        <th class="index_name level0" >group</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64level0_row0" class="row_heading level0 row0" >control</th>
#                         <td id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64row0_col0" class="data row0 col0" >0.109</td>
#                         <td id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64row0_col1" class="data row0 col1" >0.312</td>
#                         <td id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64row0_col2" class="data row0 col2" >0.009</td>
#             </tr>
#             <tr>
#                         <th id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64level0_row1" class="row_heading level0 row1" >treatment</th>
#                         <td id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64row1_col0" class="data row1 col0" >0.118</td>
#                         <td id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64row1_col1" class="data row1 col1" >0.323</td>
#                         <td id="T_e2088ad8_a52a_11eb_9acc_f06e0be46b64row1_col2" class="data row1 col2" >0.009</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### What would you advise the engineering team to do moving forward?

# %%
print("don't move forward because there's no significant impact ")
# Out:
# don't move forward because there's no significant impact
