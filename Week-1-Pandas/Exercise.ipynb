# %% [markdown]
# # Data wrangling with Pandas exercise
# * For this exercise we will be using the `listings.csv` data file.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load in the data file using `pd.read_csv()`

# %%
# Load data here
df = pd.read_csv('data/listings.csv', sep = ',')
df.head()
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 1  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68688  -73.95596
# 3      Rebecca            Brooklyn         Sunset Park  40.66120  -73.99423
# 4     Shunichi           Manhattan      Hell's Kitchen  40.76489  -73.98493
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ## Exercise 2 - Filtering
#
# Return the following subsets of the dataframe.
#
# 1. How many listings are there with a price less than 100?
#
#
# 2. Find how many listings there are in just Brooklyn.
#
#
# 3. Find how many listings there are in Brooklyn with a price less than 100.
#
#
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
#
#
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  The prices for all other listings should be the same as the were before.
#
#
# 6. What % of the rooms are private, and what % of the rooms are shared.
#     * Hint, use `.value_counts()`

# %%
# 1. How many listings are there with a price less than 100? 

df['new_price'] = df['price'] < 100
df['new_price'].value_counts()
# Out:
# False    23749
# True     22778
# Name: new_price, dtype: int64

# %%
# 2. Make a new DataFrame of listings in Brooklyn named `df_bk` 
# and find how many listings in just Brooklyn.
df['df_bk'] = df['neighbourhood_group'] == 'Brooklyn'
df['df_bk'].value_counts()

# same result
# dfBK['neighbourhood_group' == 'Brooklyn']
# len(dfBK)
# Out:
# False    27895
# True     18632
# Name: df_bk, dtype: int64

# %%
# 3. Find how many listings there are in Brooklyn with a price less than 100.

condition_1 = df['price'] < 100
condition_2 = df['neighbourhood_group'] == 'Brooklyn'

df[condition_1 & condition_2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-72387c2915e4> in <module>
#       1 # 3. Find how many listings there are in Brooklyn with a price less than 100.
#       2
# ----> 3 condition_1 = df['price'] < 100
#       4 condition_2 = df['neighbourhood_group'] == 'Brooklyn'
#       5
#
# NameError: name 'df' is not defined

# %%
# 4. Using `.isin()` select anyone that has the host name of Michael, David, John, and Daniel.
list_of_host_name = ['Michael', 'David', 'John', 'Daniel']

condition = df.host_name.isin(list_of_host_name)
df[condition]
# Out:
#              id                                               name    host_id  \
# 52        16595  LOFT HAVEN ~ Six Windows ~ Bricks ~ Plants ~ Q...      64522
# 201       61747              Cozy,  Brooklyn, Prospect Park Studio     299370
# 209       62903  Beautiful modern studio apartment in heart of NYC     306605
# 220       64015                       Prime East Village 1 Bedroom     146944
# 260       74073       Food & Music Dream Apartment in Williamsburg     211877
# 349      138216                 Sunny and Spacious Designer's Home     674970
# 351      140133                    Truly Amazing Oasis In The City     622866
# 363      148201                  NYC - Sunny Greenwich Village 1br     715807
# 402      167013      Spacious modern studio apartment in Manhattan     306605
# 431      187986                  Comfort at Crossroads of Downtown     904833
# 434      189135                  Hell's Kitchen Funky 80s Hideaway     179020
# ...

# %%
# 5. Create a new column called `adjusted_price` that has $100 added to every listing in Williamsburg.  
# The prices for all other listings should be the same as the were before. 


c1 = df['neighbourhood'] == 'Williamsburg'

df['adjusted_price'] = np.where(c1, df['price'] + 100, df['price'])
df[['neighbourhood', 'price', 'adjusted_price']]
# Out:
#                    neighbourhood  price  adjusted_price
# 0                        Midtown    175             175
# 1                   Clinton Hill     75              75
# 2             Bedford-Stuyvesant     60              60
# 3                    Sunset Park    175             175
# 4                 Hell's Kitchen     65              65
# 5                Upper West Side     75              75
# 6                      Chinatown    140             140
# 7                   West Village    160             160
# 8                    South Slope     88              88
# 9                Upper West Side     85              85
# 10                  West Village     65              65
# 11                  Williamsburg    109             209
# 12                   East Harlem    239             239
# 13                   Fort Greene    182             182
# 14                   East Harlem     96              96
# 15                  Williamsburg    299             399
# ...

# %%
# 6. What % of the rooms are private, and what % of the rooms are shared.  

df['room_type'].value_counts() / df['room_type'].value_counts().sum()                                                       

# same result
# df['room_type'].vaule_counts(normalize = True)
# Out:
# Entire home/apt    0.515787
# Private room       0.454446
# Shared room        0.021213
# Hotel room         0.008554
# Name: room_type, dtype: float64

# %% [markdown]
# # Exercise 3 - Grouping
#
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
#
#
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups.
#
#
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups.
#
#
# 4. Using `groupby`, find the median price for each room type in each neighbourhood_group.
#
#
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices for each room type in each neighbourhood_group.

# %%
# 1. Using `groupby`, count how many listings are in each neighbourhood_group.
df.groupby('neighbourhood_group')['calculated_host_listings_count'].sum()
# Out:
# neighbourhood_group
# Bronx              2619
# Brooklyn          45790
# Manhattan        180430
# Queens            44534
# Staten Island       692
# Name: calculated_host_listings_count, dtype: int64

# %%
# 2. Using `groupby`, find the mean price for each of the neighbourhood_groups. 

df.groupby('neighbourhood_group')['price'].mean()
# Out:
# neighbourhood_group
# Bronx             92.751479
# Brooklyn         120.225258
# Manhattan        191.880466
# Queens            99.754965
# Staten Island    110.947214
# Name: price, dtype: float64

# %%
# 3. Using `groupby` and `.agg()`, find the min and max price for each of the neighbourhood_groups. 


df.groupby('neighbourhood_group')['price'].agg(['min', 'max'])
# Out:
#                      min    max
# neighbourhood_group
# Bronx                 16   1404
# Brooklyn               0  10000
# Manhattan              0  10000
# Queens                 0  10000
# Staten Island         19   1200

# %%
# 4. Using `groupby`, find the mean price for each room type in each neighbourhood_group.

#df.groupby('room_type')['price'].mean()

# double group by
df.groupby(['neighbourhood_group','room_type'])['price'].mean();
# Out:
# room_type
# Entire home/apt    199.395950
# Hotel room         275.015075
# Private room        91.453084
# Shared room         87.063830
# Name: price, dtype: float64

# %%
# 5. Using `groupby` and `.agg()`, find the count, min, max, mean, median, and std of the prices 
# for each room type in each neighbourhood_group.
gb_cols = ['neighbourhood_group', 'room_type']
df.groupby(gb_cols)['price'].agg(['count', 'min', 'max', 'mean', 'median', 'std'])
# Out:
#                                      count  min    max        mean  median  \
# neighbourhood_group room_type
# Bronx               Entire home/apt    415   25   1404  138.004819     103
#                     Private room       722   16    700   68.419668      55
#                     Shared room         46   20    800   66.391304      44
# Brooklyn            Entire home/apt   9112   20  10000  171.587687     135
#                     Hotel room          30    0    399  147.300000     129
#                     Private room      9159   10   2500   71.291189      60
#                     Shared room        331   15   1500   57.870091      36
# Manhattan           Entire home/apt  12209    0  10000  231.335572     165
#                     Hotel room         351    0   2211  292.515670     210
#                     Private room      7601   10  10000  128.277069      80
#                     Shared room        419   10  10000  111.735084      60
# ...

# %% [markdown]
# # Join and file saving.
# 1. Load the `prices.csv` and the `n_listings.csv`
#
#
# 2. Do join that keeps all the records for each table.
#     * Neighbourhood groups should include ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'LongIsland']
#
#
# 3. Save your joined csv as `joined.csv`
#
#
# 4. Load your saved table and see if it looks the same or different that the DataFrame you used to create it.

# %%
# 1. Load the `prices.csv` and the `n_listings.csv`

dfprices = pd.read_csv('data/prices.csv',sep = ',')
dfprices
dflistings = pd.read_csv('data/n_listings.csv', sep = ';')

# %%
# 2. Do join that keeps all the records for each table.

dfjoined = pd.merge(dfprices, dflistings, on='neighbourhood_group', how='outer')
dfjoined
# Out:
#   neighbourhood_group  mean_price  n_listings
# 0               Bronx   92.751479      1183.0
# 1            Brooklyn  120.225258     18632.0
# 2           Manhattan  191.880466     20580.0
# 3              Queens   99.754965         NaN
# 4       Staten Island  110.947214         NaN
# 5          LongIsland         NaN      4121.0

# %%
#3 Save your joined csv as joined.csv

save_as = 'joined.csv'
df.to_csv(save_as, index=False) 

#4 Load your saved table and see if it looks the same or different 
#that the DataFrame you used to create it.
dfoutcome = pd.read_csv('joined.csv')
dfoutcome
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...       4869
# 2          5121                                    BlissArtsSpace!       7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden       7378
# 4          5178                   Large Furnished Room Near B'way　       8967
# 5          5203                 Cozy Clean Guest Room - Family Apt       7490
# 6          5238                 Cute & Cozy Lower East Side 1 bdrm       7549
# 7          5552            Spacious river view in the West Village       8380
# 8          5803     Lovely Room 1, Garden, Best Area, Legal rental       9744
# 9          6021  Wonderful Guest Bedroom in Manhattan CENTRAL PARK      11528
# 10         6090                      West Village Nest - Superhost      11975
# ...

# %% [markdown]
# # Use the grammys.csv data for the next section of questions.
#
# 1. Who was won Album of the Year in 2016?
#
#
# 2. Who won Best Rap Album in 2009?
#
#
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

# %%
df1 = pd.read_csv('data/grammys.csv')
df1
# Out:
#       year                                           category  \
# 0     1959                                  Album of the Year
# 1     1959                                   Best Album Cover
# 2     1959                                   Best Arrangement
# 3     1959  Best Classical Performance - Chamber Music (in...
# 4     1959  Best Classical Performance - Instrumentalist (...
# 5     1959  Best Classical Performance - Instrumentalist (...
# 6     1959  Best Classical Performance - Instrumentalist (...
# 7     1959    Best Classical Performance - Operatic or Choral
# 8     1959             Best Classical Performance - Orchestra
# 9     1959  Best Classical Performance - Vocal Soloist (wi...
# 10    1959                            Best Comedy Performance
# 11    1959                 Best Country & Western Performance
# 12    1959               Best Country and Western Performance
# 13    1959                 Best Engineered Record (Classical)
# ...

# %%
#  1. Who was won Album of the Year in 2016?
condition1 = df1['year'] == 2016
condition2 = df1['winner'] == True
df1[condition1 & condition2]
# Out:
#       year                                           category  \
# 5505  2016                                  Album of the Year
# 5509  2016                                   Best Album Notes
# 5510  2016                       Best Alternative Music Album
# 5513  2016                    Best American Roots Performance
# 5514  2016                           Best American Roots Song
# 5515  2016                               Best Americana Album
# 5516  2016       Best Arrangement, Instrumental or a Cappella
# 5517  2016           Best Arrangement, Instruments and Vocals
# 5518  2016                               Best Bluegrass Album
# 5519  2016                                   Best Blues Album
# 5520  2016      Best Boxed or Special Limited Edition Package
# 5521  2016      Best Chamber Music/Small Ensemble Performance
# 5522  2016                              Best Children's Album
# 5523  2016                            Best Choral Performance
# ...

# %%
# 2. Who won Best Rap Album in 2009?
condition1 = df1['year'] == 2009
condition2 = df1['category'] == 'Best Rap Album'
condition3 = df1['winner'] == True
df1[condition1 & condition2 & condition3]
# Out:
#       year        category         nominee     workers  winner
# 4396  2009  Best Rap Album  Tha Carter III  Lil' Wayne    True

# %%
# 3. How many awards was Kendrick Lamar nomiated for, and how many did he win...?

condition1 = df1['workers'] == 'Kendrick Lamar'

df1['get_nomiated'] = np.where(condition1, 1, 0)
#count the times when condition1 is true to get how many times KL is nomiated,
print(df1['get_nomiated'].value_counts())

condition2 = df1['winner'] == True
df1['win'] = np.where(condition1&condition2, 1, 0)
df1['win'].value_counts()
# Out:
# 0    6317
# 1       6
# Name: get_nomiated, dtype: int64
# 0    6319
# 1       4
# Name: win, dtype: int64
